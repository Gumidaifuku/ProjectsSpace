// %% [markdown]
// # Java入門編 2-1 Java言語の基本の動き

// %% [markdown]
// **文字を出力してみる**

// %%
//こちらのセルを実行してみましょう
public class PrintTest{
    public static void hello(){

        System.out.println("こんにちは！");

    }
}
PrintTest.hello();
// Out:
// こんにちは！

// %%
# modcell: test1
# 合言葉を記入↓
answer = 'testAnswer'
    
class className():
    def __init__(self, strA):
        self.strA = answer

// %% [markdown]
// **文字の出力を書いてみる**
// 下のセルのhelloメソッドの中に文字を出力する為のコードを書いてみましょう

// %%
public class PrintTest{
    public static void hello(){

        

    }
}
PrintTest.hello();

// %%
# modcell: test2
# 合言葉を記入↓
answer = 'testAnswer'
    
class className():
    def __init__(self, strA):
        self.strB = answer
// Out:
// |   # modcell: tagname
// '#'は不正な文字です
//
// |   # modcell: tagname
// 式の開始が不正です

// %% [markdown]
// **複数の文字を出力してみる**

// %%
//こちらのセルを実行してみましょう
public class PrintTest{
    public static void hello(){

        System.out.println("こんにちは！");
         System.out.println("さようなら");

    }
}
PrintTest.hello();
// Out:
// こんにちは！
// さようなら

// %%
# modcell: test3
# 合言葉を記入↓
answer = 'testAnswer'
    
class className():
    def __init__(self, strA):
        self.strC = answer

// %% [markdown]
// **複数の文字の出力を書いてみる**
// 下のセルのhellosメソッドの中に文字を複数出力する為のコードを書いてみましょう

// %%
public class PrintTest2{
    public static void hellos(){

        

    }
}
PrintTest2.hellos();

// %%
# modcell: test4
# 合言葉を記入↓
answer = 'testAnswer'
    
class className():
    def __init__(self, strA):
        self.strD = answer

// %%
# modcell: title

title = 'Java入門編 2-1 Java言語の基本の動き'
    
class className():
    def __init__(self, strA):
        self.strTitle = title
// Out:
// |   # modcell: title
// '#'は不正な文字です
//
// |   # modcell: title
// 式の開始が不正です
