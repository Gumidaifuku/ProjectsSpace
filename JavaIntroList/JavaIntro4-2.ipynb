// %% [markdown]
// # Java入門編 4-2 メソッドの引数

// %%
# modcell: test1
# 解答を記入↓
answer = 'notestAnswer'
    
class className():
    def __init__(self, strA):
        self.strA = answer

// %%
# modcell: test2
# 解答を記入↓
answer = 'nottestAnswer'
    
class className():
    def __init__(self, strA):
        self.strB = answer

// %%
# modcell: test3
# 解答を記入↓
answer = 'nottestAnswer'
    
class className():
    def __init__(self, strA):
        self.strC = answer

// %%
# modcell: test4
# 解答を記入↓
answer = 'nottestAnswer'
    
class className():
    def __init__(self, strA):
        self.strD = answer

// %%
# modcell: title

title = 'Java入門編 4-2 メソッドの引数'
    
class className():
    def __init__(self, strA):
        self.strTitle = title
